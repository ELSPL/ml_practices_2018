# 2    positif
# 3    positif
# 4    positif
# 5    positif
# 6    positif
# 7    negatif
# 8    positif
# 9    negatif
# 10   positif
# 11   positif
# 12   negatif
# 13   negatif
# 14   positif
# 15   negatif
# 16   negatif
# 17   positif
# 18   negatif
# 19   positif
# 20   negatif
# 21   negatif
# 22   negatif
# 23   positif
# 24   negatif
# 25   positif
# 26   negatif
# 27   negatif
# 28   negatif
# 29   negatif
# ..       ...
# 362  negatif
# 363  positif
# 364  negatif
# 365  negatif
# 366  negatif
# 367  positif
# 368  positif
# 369  negatif
# 370  negatif
# 371  positif
# 372  negatif
# 373  negatif
# 374  positif
# 375  positif
# 376  negatif
# 377  negatif
# 378  negatif
# 379  positif
# 380  negatif
# 381  negatif
# 382  negatif
# 383  negatif
# 384  negatif
# 385  positif
# 386  negatif
# 387  positif
# 388  positif
# 389  negatif
# 390  negatif
# 391  negatif
#
# [392 rows x 9 columns]

# %% [markdown]
# # Data Cleaning

# %%
pima.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 9 columns):
# pregnant     392 non-null int64
# glucose      392 non-null int64
# diastolic    392 non-null int64
# triceps      392 non-null int64
# insulin      392 non-null int64
# bmi          392 non-null float64
# diabetes     392 non-null float64
# age          392 non-null int64
# test         392 non-null object
# dtypes: float64(2), int64(6), object(1)
# memory usage: 27.6+ KB

# %% [markdown]
# ### Figuring out number of null values in each column

# %%
pima.isnull().sum()
# Out:
# pregnant     0
# glucose      0
# diastolic    0
# triceps      0
# insulin      0
# bmi          0
# diabetes     0
# age          0
# test         0
# dtype: int64

# %% [markdown]
# ** Hence, there are no missing values in the dataset. **

# %% [markdown]
# ## Target Variable :

# %%
pima.test.unique()
# Out:
# array(['negatif', 'positif'], dtype=object)

# %% [markdown]
# ### There are 2 classes -
# ```
#     1. negatif - no diabetes
#     2. positif - diabetes
#
# Replacing the classes :
#     0 - negatif
#     1 - positif
# ```

# %%
pima = pima.replace(('negatif', 'positif'), (0,1))

# %%
# Converting the type of target variable to bool.
pima.test = pima.test.astype(bool)

# %%
pima.dtypes
# Out:
# pregnant       int64
# glucose        int64
# diastolic      int64
# triceps        int64
# insulin        int64
# bmi          float64
# diabetes     float64
# age            int64
# test            bool
# dtype: object

# %%
pima
# Out:
#      pregnant  glucose  diastolic  triceps  insulin   bmi  diabetes  age  \
# 0           1       89         66       23       94  28.1     0.167   21
# 1           0      137         40       35      168  43.1     2.288   33
# 2           3       78         50       32       88  31.0     0.248   26
# 3           2      197         70       45      543  30.5     0.158   53
# 4           1      189         60       23      846  30.1     0.398   59
# 5           5      166         72       19      175  25.8     0.587   51
# 6           0      118         84       47      230  45.8     0.551   31
# 7           1      103         30       38       83  43.3     0.183   33
# 8           1      115         70       30       96  34.6     0.529   32
# 9           3      126         88       41      235  39.3     0.704   27
# 10         11      143         94       33      146  36.6     0.254   51
# 11         10      125         70       26      115  31.1     0.205   41
# 12          1       97         66       15      140  23.2     0.487   22
# 13         13      145         82       19      110  22.2     0.245   57
# 14          3      158         76       36      245  31.6     0.851   28
# 15          3       88         58       11       54  24.8     0.267   22
# 16          4      103         60       33      192  24.0     0.966   33
# 17          4      111         72       47      207  37.1     1.390   56
# 18          3      180         64       25       70  34.0     0.271   26
# 19          9      171        110       24      240  45.4     0.721   54
# 20          1      103         80       11       82  19.4     0.491   22
# 21          1      101         50       15       36  24.2     0.526   26
# 22          5       88         66       21       23  24.4     0.342   30
# 23          8      176         90       34      300  33.7     0.467   58
# 24          7      150         66       42      342  34.7     0.718   42
# 25          7      187         68       39      304  37.7     0.254   41
# 26          0      100         88       60      110  46.8     0.962   31
# 27          0      105         64       41      142  41.5     0.173   22
# 28          2      141         58       34      128  25.4     0.699   24
# 29          1       95         66       13       38  19.6     0.334   25
# ..        ...      ...        ...      ...      ...   ...       ...  ...
# 362         2      127         46       21      335  34.4     0.176   22
# 363         2       93         64       32      160  38.0     0.674   23
# 364         3      158         64       13      387  31.2     0.295   24
# 365         5      126         78       27       22  29.6     0.439   40
# 366         0      134         58       20      291  26.4     0.352   21
# 367         7      187         50       33      392  33.9     0.826   34
# 368         3      173         78       39      185  33.8     0.970   31
# 369         1      108         60       46      178  35.5     0.415   24
# 370         1      114         66       36      200  38.1     0.289   21
# 371         1      149         68       29      127  29.3     0.349   42
# 372         5      117         86       30      105  39.1     0.251   42
# 373         1      116         78       29      180  36.1     0.496   25
# 374         3      130         78       23       79  28.4     0.323   34
# 375         2      174         88       37      120  44.5     0.646   24
# 376         2      106         56       27      165  29.0     0.426   22
# 377         0      126         86       27      120  27.4     0.515   21
# 378         2       99         60       17      160  36.6     0.453   21
# 379        11      120         80       37      150  42.3     0.785   48
# 380         3      102         44       20       94  30.8     0.400   26
# 381         1      109         58       18      116  28.5     0.219   22
# 382        13      153         88       37      140  40.6     1.174   39
# 383        12      100         84       33      105  30.0     0.488   46
# 384         1       81         74       41       57  46.3     1.096   32
# 385         3      187         70       22      200  36.4     0.408   36
# 386         1      121         78       39       74  39.0     0.261   28
# 387         0      181         88       44      510  43.3     0.222   26
# 388         1      128         88       39      110  36.5     1.057   37
# 389         2       88         58       26       16  28.4     0.766   22
# 390        10      101         76       48      180  32.9     0.171   63
# 391         5      121         72       23      112  26.2     0.245   30
#
#       test
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7    False
# 8     True
# 9    False
# 10    True
# 11    True
# 12   False
# 13   False
# 14    True
# 15   False
# 16   False
# 17    True
# 18   False
# 19    True
# 20   False
# 21   False
# 22   False
# 23    True
# 24   False
# 25    True
# 26   False
# 27   False
# 28   False
# 29   False
# ..     ...
# 362  False
# 363   True
# 364  False
# 365  False
# 366  False
# 367   True
# 368   True
# 369  False
# 370  False
# 371   True
# 372  False
# 373  False
# 374   True
# 375   True
# 376  False
# 377  False
# 378  False
# 379   True
# 380  False
# 381  False
# 382  False
# 383  False
# 384  False
# 385   True
# 386  False
# 387   True
# 388   True
# 389  False
# 390  False
# 391  False
#
# [392 rows x 9 columns]

# %% [markdown]
# # Data visualization :

# %%
sns.countplot(pima.test)

# %%
pima.plot.pie(y='test', figsize=(5, 5))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-aa561556b068> in <module>()
# ----> 1 pima.plot.pie(y='test', figsize=(5, 5))
#
# /home/heenal/anaconda2/lib/python2.7/site-packages/pandas/plotting/_core.pyc in pie(self, y, **kwds)
#    3378
#    3379         """
# -> 3380         return self(kind='pie', y=y, **kwds)
#    3381
#    3382     def scatter(self, x, y, s=None, c=None, **kwds):
#
# /home/heenal/anaconda2/lib/python2.7/site-packages/pandas/plotting/_core.pyc in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# /home/heenal/anaconda2/lib/python2.7/site-packages/pandas/plotting/_core.pyc in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1975                  yerr=yerr, xerr=xerr,
#    1976                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1977                  **kwds)
#    1978
#    1979
#
# /home/heenal/anaconda2/lib/python2.7/site-packages/pandas/plotting/_core.pyc in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1802         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1803
# -> 1804     plot_obj.generate()
#    1805     plot_obj.draw()
#    1806     return plot_obj.result
#
# /home/heenal/anaconda2/lib/python2.7/site-packages/pandas/plotting/_core.pyc in generate(self)
#     256     def generate(self):
#     257         self._args_adjust()
# --> 258         self._compute_plot_data()
#     259         self._setup_subplots()
#     260         self._make_plot()
#
# /home/heenal/anaconda2/lib/python2.7/site-packages/pandas/plotting/_core.pyc in _compute_plot_data(self)
#     371         if is_empty:
#     372             raise TypeError('Empty {0!r}: no numeric data to '
# --> 373                             'plot'.format(numeric_data.__class__.__name__))
#     374
#     375         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot

# %%
pima.test.value_counts()
# Out:
# 0    262
# 1    130
# Name: test, dtype: int64

# %% [markdown]
# ### Out of the total patients, nearly 33.33% of them show signs of diabetes.

# %%
g = sns.pairplot(pima, hue="test")

# %%
sns.set(rc={'figure.figsize':(15,15)})
sns.boxplot(data=pima)

# %% [markdown]
# # Age - continuous variable

# %%
pima.groupby(['age']).test.value_counts().sort_index().unstack()
# Out:
# test     0    1
# age
# 21    31.0  2.0
# 22    38.0  5.0
# 23    25.0  3.0
# 24    25.0  6.0
# 25    21.0  9.0
# 26    19.0  5.0
# 27    11.0  3.0
# 28    14.0  7.0
# 29     6.0  8.0
# 30     7.0  3.0
# 31     5.0  7.0
# 32     3.0  3.0
# 33     4.0  7.0
# 34     6.0  2.0
# 35     3.0  3.0
# 36     2.0  5.0
# 37     6.0  2.0
# 38     1.0  2.0
# 39     6.0  1.0
# 40     3.0  3.0
# 41     2.0  3.0
# 42     4.0  3.0
# 43     2.0  7.0
# 44     NaN  1.0
# 45     2.0  2.0
# 46     2.0  4.0
# 47     1.0  2.0
# 48     2.0  1.0
# 49     2.0  NaN
# 50     1.0  1.0
# 51     1.0  5.0
# 52     NaN  2.0
# 53     NaN  3.0
# 54     NaN  2.0
# 55     1.0  1.0
# 56     NaN  1.0
# 57     1.0  1.0
# 58     1.0  3.0
# 59     NaN  1.0
# 60     1.0  1.0
# 61     1.0  NaN
# 63     1.0  NaN
# 81     1.0  NaN

# %%
sns.jointplot(x='age', y='test', data=pima, kind='kde')

# %%
pima.groupby(['test']).agg({'age':'mean'})
# Out:
#             age
# test
# 0     28.347328
# 1     35.938462

# %%
pima.groupby(['test']).agg({'age':'median'})
# Out:
#       age
# test
# 0      25
# 1      33

# %% [markdown]
# ### The group showing signs of diabetes( i.e. test = 1) have higher mean age than its counterpart.

# %% [markdown]
# # Pregnant
# ```
# It represents the number of times the woman got pregnant during her life.
# ```

# %%
pima.groupby(['pregnant']).test.value_counts().sort_index().unstack()
# Out:
# test         0     1
# pregnant
# 0         37.0  19.0
# 1         73.0  20.0
# 2         52.0  12.0
# 3         26.0  19.0
# 4         21.0   6.0
# 5         13.0   8.0
# 6         15.0   4.0
# 7         10.0  10.0
# 8          3.0  11.0
# 9          5.0   6.0
# 10         3.0   3.0
# 11         NaN   5.0
# 12         2.0   3.0
# 13         2.0   1.0
# 14         NaN   1.0
# 15         NaN   1.0
# 17         NaN   1.0

# %%
sns.catplot('pregnant', col='test', data=pima, kind='count')

# %% [markdown]
# ### The group not showing signs of diabetes comprises of the women having lesser pregnancies whereas the group showing signs of diabetes is almost evenly distributed over any number of pregnancies.

# %%
sns.catplot(x='pregnant',y='age', col='test', data=pima)

# %%
sns.lmplot(x='pregnant', y='age',hue='test', data=pima)

# %% [markdown]
# ### We can say that higher number of pregnancies are prevalent only in older aged women.

# %% [markdown]
# # Glucose

# %%
sns.barplot(x='test', y='glucose', data=pima)

# %%
pima.groupby(['test']).agg({'glucose':'mean'})
# Out:
#          glucose
# test
# 0     111.431298
# 1     145.192308

# %% [markdown]
# ### Mean glucose level of people showing signs of diabetes is around 145 and of their counterpart is low, 111.

# %% [markdown]
# # Insulin
# ```
# It represents the rate of insulin 2 hours serum insulin (mu U/ml).
# ```

# %%
pima.groupby(['test']).agg({'insulin':'mean'})
# Out:
#          insulin
# test
# 0     130.854962
# 1     206.846154

# %%
sns.boxplot(pima.test, pima.insulin)

# %% [markdown]
# ### The IQR ranges at higher insulin levels for those showing signs of diabetes.

# %%
sns.lmplot(x='glucose', y='insulin',hue='test', data=pima)

# %% [markdown]
# ### 1.  High glucose and high insulin together lead to the patient showing sign of diabetes to some extent.
# ### 2. Glucose and insulin are correlated to some extent.

# %% [markdown]
# # Diastolic Blood Pressure
# ```
# The blood pressure is a very well-known way to measure the health of the heart of a person, there are too measure in fact, the diastolic and the systolic. In this data set, we have the diastolic which is in the fact the pressure in (mm/Hg) when the heart relaxed after the contraction.
# ```

# %%
sns.barplot(x='test', y='diastolic', data=pima)

# %%
pima.groupby(['test']).agg({'diastolic':'mean'})
# Out:
#       diastolic
# test
# 0     68.969466
# 1     74.076923

# %%
sns.boxplot(pima.test, pima.diastolic)

# %% [markdown]
# ### The mean diastolic blood pressure of people showing signs of diabetes is slightly higher than their counterparts.

# %% [markdown]
# # Triceps
# ```
# It is a value used to estimate body fat (mm) which is measured on the right arm halfway between the olecranon process of the elbow and the acromial process of the scapula.
#
# ```

# %%
pima.groupby(['test']).agg({'triceps':'mean'})
# Out:
#         triceps
# test
# 0     27.251908
# 1     32.961538

# %%
sns.boxplot(pima.test, pima.triceps)

# %% [markdown]
# ### The mean value of Triceps of those showing signs of diabetes is higher than its counterpart.

# %% [markdown]
# # BMI
# ```
# It represents the Body Mass Index (weight in kg / (height in meters squared), and is an indicator of the health of a person.
# ```

# %%
pima.groupby(['test']).agg({'bmi':'mean'})
# Out:
#             bmi
# test
# 0     31.750763
# 1     35.777692

# %%
sns.boxplot(pima.test, pima.bmi)

# %% [markdown]
# ### 1. The BMI of those not showing sign of diabetes has a higher variability.
# ### 2. The average BMI of those showing signs of diabetes is slightly higher than its counterpart.

# %%
sns.lmplot(x='bmi', y='triceps',hue='test', data=pima)

# %% [markdown]
# ### 1. Triceps and BMI have a strong correlation.
# ### 2. Higher values of both triceps and BMI together show signs of diabetes to some extent.

# %% [markdown]
# # History of Diabetes
# ```
# It is an indicator of history of diabetes in the family.
# ```

# %%
pima.groupby(['test']).agg({'diabetes':'mean'})
# Out:
#       diabetes
# test
# 0     0.472168
# 1     0.625585

# %%
sns.set(rc={'figure.figsize':(6,4)})
sns.boxplot(pima.test, pima.diabetes)

# %% [markdown]
# ### The history of diabetes does seem to have some influence on showing signs of diabetes by the woman.

# %%
sns.set(rc={'figure.figsize':(15,13)})
ax = sns.heatmap(pima.corr(),annot=True)
