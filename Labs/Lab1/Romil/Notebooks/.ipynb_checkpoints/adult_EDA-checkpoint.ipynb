# %%
#importing necessary packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import missingno as msno
import seaborn as sns
import scipy.stats as st

# %% [markdown]
# ** fnlwgt – The \# of people the census takers believe that observation represents. **

# %%
#reading a file and adding column names to it.
names=['age','workclass','fnlwgt','education','education_num','marital_status','occupation','relationship','race','sex','capial_gain','capital_loss','hours_per_week','native_country','salary']
data = pd.read_csv('../Data/adult.csv',header=None,names=names)
data
# Out:
#        age          workclass    fnlwgt      education  education_num  \
# 0       39          State-gov   77516.0      Bachelors           13.0
# 1       50   Self-emp-not-inc   83311.0      Bachelors           13.0
# 2       38            Private  215646.0        HS-grad            9.0
# 3       53            Private  234721.0           11th            7.0
# 4       28            Private  338409.0      Bachelors           13.0
# 5       37            Private  284582.0        Masters           14.0
# 6       49            Private  160187.0            9th            5.0
# 7       52   Self-emp-not-inc  209642.0        HS-grad            9.0
# 8       31            Private   45781.0        Masters           14.0
# 9       42            Private  159449.0      Bachelors           13.0
# 10      37            Private  280464.0   Some-college           10.0
# 11      30          State-gov  141297.0      Bachelors           13.0
# ...

# %%
data.shape
# Out:
# (17458, 15)

# %%
data.dtypes
# Out:
# age                 int64
# workclass          object
# fnlwgt            float64
# education          object
# education_num     float64
# marital_status     object
# occupation         object
# relationship       object
# race               object
# sex                object
# capial_gain       float64
# capital_loss      float64
# hours_per_week    float64
# native_country     object
# salary             object
# dtype: object

# %%
data[data.salary == True]
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, education_num, marital_status, occupation, relationship, race, sex, capial_gain, capital_loss, hours_per_week, native_country, salary]
# Index: []

# %%
data = data.replace('?',np.NaN)
data
# Out:
#        age          workclass    fnlwgt      education  education_num  \
# 0       39          State-gov   77516.0      Bachelors           13.0
# 1       50   Self-emp-not-inc   83311.0      Bachelors           13.0
# 2       38            Private  215646.0        HS-grad            9.0
# 3       53            Private  234721.0           11th            7.0
# 4       28            Private  338409.0      Bachelors           13.0
# 5       37            Private  284582.0        Masters           14.0
# 6       49            Private  160187.0            9th            5.0
# 7       52   Self-emp-not-inc  209642.0        HS-grad            9.0
# 8       31            Private   45781.0        Masters           14.0
# 9       42            Private  159449.0      Bachelors           13.0
# 10      37            Private  280464.0   Some-college           10.0
# 11      30          State-gov  141297.0      Bachelors           13.0
# ...

# %%
data.isnull().sum()
# Out:
# age               0
# workclass         1
# fnlwgt            1
# education         1
# education_num     1
# marital_status    1
# occupation        1
# relationship      1
# race              1
# sex               1
# capial_gain       1
# capital_loss      1
# hours_per_week    1
# native_country    1
# salary            1
# dtype: int64

# %%
sns.heatmap(data.corr(),annot=True)

# %%
data = data.dropna()

# %%
data.dtypes
# Out:
# age                 int64
# workclass          object
# fnlwgt            float64
# education          object
# education_num     float64
# marital_status     object
# occupation         object
# relationship       object
# race               object
# sex                object
# capial_gain       float64
# capital_loss      float64
# hours_per_week    float64
# native_country     object
# salary             object
# dtype: object

# %%
sns.pairplot(data, hue = 'salary')

# %% [markdown]
# ## Observation:
# ```
# In the above pair plot, we are not able to see any two features which are linearly separable. Their distribution graph is also overlapping.
# ```

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ## Salary

# %%
data.salary.value_counts().plot(kind = 'bar')

# %% [markdown]
#   ## Race

# %%
sns.set(rc={'figure.figsize':(15,8)})
data.race.value_counts().plot(kind = 'bar')

# %% [markdown]
# ## Sex

# %%
data.sex.value_counts().plot(kind = 'bar')

# %% [markdown]
# ## Marital Status

# %%
data.marital_status.value_counts().plot(kind = 'bar')

# %% [markdown]
# ## Relationship

# %%
data.relationship.value_counts().plot(kind = 'bar')

# %% [markdown]
# ## Occupation

# %%
data.occupation.value_counts().plot(kind = 'bar')

# %% [markdown]
# ## Native country

# %%
data.native_country.value_counts().plot(kind = 'bar')

# %% [markdown]
# ## Education-num

# %%
data.education_num.hist()

# %% [markdown]
# ## Work hours per week

# %%
data.hours_per_week.hist()

# %%
data.groupby('education').salary.value_counts().unstack().plot(kind = 'bar')
