# %%
# Importing all necessary packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder

# %%
mush = pd.read_csv('../Data/mushroom.csv' , header= None)

# %%
mush.columns = ['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor', 'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color', 'stalk-shape', 'stalk-root', 'stalk-surface-above-ring', 'stalk-surface-below-ring', 'stalk-color-above-ring', 'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number', 'ring-type', 'spore-print-color', 'population', 'habitat']

# %%
mush
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# 5        e         x           y         y       t    a               f
# 6        e         b           s         w       t    a               f
# 7        e         b           y         w       t    l               f
# 8        p         x           y         w       t    p               f
# 9        e         b           s         y       t    a               f
# 10       e         x           y         y       t    l               f
# 11       e         x           y         y       t    a               f
# ...

# %% [markdown]
# ### Since, all the columns are in categorical format, we convert them to numerical form.

# %%
lbe = LabelEncoder()
mush_new = mush.apply(lbe.fit_transform)

# %%
mush_new
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# 5         0          5            3          9        1     0
# 6         0          0            2          8        1     0
# 7         0          0            3          8        1     3
# 8         1          5            3          8        1     6
# 9         0          0            2          9        1     0
# 10        0          5            3          9        1     3
# 11        0          5            3          9        1     0
# 12        0          0            2          9        1     0
# 13        1          5            3          8        1     6
# ...

# %% [markdown]
# # Data Cleaning

# %%
mush.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
# class                       8124 non-null object
# cap-shape                   8124 non-null object
# cap-surface                 8124 non-null object
# cap-color                   8124 non-null object
# bruises                     8124 non-null object
# odor                        8124 non-null object
# gill-attachment             8124 non-null object
# gill-spacing                8124 non-null object
# gill-size                   8124 non-null object
# gill-color                  8124 non-null object
# stalk-shape                 8124 non-null object
# stalk-root                  8124 non-null object
# stalk-surface-above-ring    8124 non-null object
# stalk-surface-below-ring    8124 non-null object
# stalk-color-above-ring      8124 non-null object
# stalk-color-below-ring      8124 non-null object
# veil-type                   8124 non-null object
# ...

# %% [markdown]
# ### Figuring out number of null values in each column

# %%
mush.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
mush['stalk-root'].unique()
# Out:
# array(['e', 'c', 'b', 'r', '?'], dtype=object)

# %%
mush[mush['stalk-root'] == '?'].shape[0]
# Out:
# 2480

# %%
mush_new['stalk-root'].unique()
# Out:
# array([3, 2, 1, 4, 0])

# %%
mush_new[mush_new['stalk-root'] == 0].shape[0]
# Out:
# 2480

# %% [markdown]
# ### There are 2480 rows with '?' in their stalk-root value.

# %%
# Separating the missing stalk-root mushrooms from the original dataset
# m1 = missing stalk-root mushrooms
m1 = mush_new[mush_new['stalk-root'] == 0]

# m2 = rest of the mushrooms
m2 = mush_new[mush_new['stalk-root'] != 0]
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 3984      0          5            3          0        1     5
# 4023      1          5            3          2        0     8
# 4076      0          2            3          7        0     5
# 4100      1          5            3          2        0     8
# 4104      1          5            3          4        0     2
# 4196      1          5            3          4        0     8
# 4200      1          5            3          4        0     8
# 4283      0          2            2          5        1     5
# 4291      0          3            2          5        1     5
# 4326      0          5            3          6        0     5
# 4329      1          5            3          4        0     7
# 4331      1          3            3          4        0     5
# 4357      0          5            2          2        1     5
# 4376      1          5            3          4        0     8
# ...

# %%
sns.countplot(m2['class'])
plt.show()

# %% [markdown]
# # Data visualization

# %% [markdown]
# ## Checking the balance between the classes of the target variable

# %%
#sns.set(rc={'figure.figsize':(8,5)})
sns.countplot(mush['class'])
plt.show()

# %% [markdown]
# ### Data is split almost equally among the 2 classes i.e. class - poisonous or edible.

# %%
g = sns.pairplot(mush_new, hue='class')
# Out:
# /home/heenal/anaconda2/lib/python2.7/site-packages/statsmodels/nonparametric/kde.py:488: RuntimeWarning: invalid value encountered in divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /home/heenal/anaconda2/lib/python2.7/site-packages/statsmodels/nonparametric/kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /home/heenal/anaconda2/lib/python2.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
sns.set(rc={'figure.figsize':(15,13)})
ax = sns.heatmap(mush_new.corr(),annot=True)
# Out:
# /home/heenal/anaconda2/lib/python2.7/site-packages/numexpr/cpuinfo.py:42: UserWarning: [Errno 12] Cannot allocate memory
#   warnings.warn(str(e), UserWarning, stacklevel=stacklevel)

# %% [markdown]
# # Bruises

# %%
sns.catplot('bruises', col='stalk-root', data=m2, kind='count')

# %%
sns.catplot('gill-size', col='stalk-root', data=m2, kind='count')

# %%
sns.catplot('gill-color', col='stalk-root', data=m2, kind='count')

# %%
sns.catplot('ring-type', col='stalk-root', data=m2, kind='count')

# %% [markdown]
# # Checking the various stalk-roots in different habitats

# %%
sns.catplot('habitat', col='stalk-root', data=m2, kind='count')

# %%
sns.catplot('habitat', col='stalk-root', data=m1, kind='count')

# %% [markdown]
# ### Observation :
# ```
# 1. Only this missing type of stalk-rooted mushrooms are found in habitat '6' i.e. waste areas.
# 2. As many as 800 mushrooms of this type are found in leafy origins, habitat '2'. No other stalk-root type is prevalent in such a habitat.
#
# We may guess this missing type of stalk-root to be unique and hence, may consider it to be given a new category.
# ```

# %%
sns.catplot('spore-print-color', col='class', data=mush_new, kind='count')

# %%
sns.catplot('spore-print-color', col='class', data=m2, kind='count')
