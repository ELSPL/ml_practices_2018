# %%
# Importing the necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('../Data/Credit_Card_Applications.csv')

# %%
data.head()
# Out:
#    CustomerID  A1     A2     A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 0    15776156   1  22.08  11.46   2   4   4  1.585   0   0    0    1    2
# 1    15739548   0  22.67   7.00   2   8   4  0.165   0   0    0    0    2
# 2    15662854   0  29.58   1.75   1   4   4  1.250   0   0    0    1    2
# 3    15687688   0  21.67  11.50   1   5   3  0.000   1   1   11    1    2
# 4    15715750   1  20.17   8.17   2   6   4  1.960   1   1   14    0    2
#
#    A13   A14  Class
# 0  100  1213      0
# 1  160     1      0
# 2  280     1      0
# 3    0     1      1
# 4   60   159      1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 16 columns):
# CustomerID    690 non-null int64
# A1            690 non-null int64
# A2            690 non-null float64
# A3            690 non-null float64
# A4            690 non-null int64
# A5            690 non-null int64
# A6            690 non-null int64
# A7            690 non-null float64
# A8            690 non-null int64
# A9            690 non-null int64
# A10           690 non-null int64
# A11           690 non-null int64
# A12           690 non-null int64
# A13           690 non-null int64
# A14           690 non-null int64
# Class         690 non-null int64
# dtypes: float64(3), int64(13)
# memory usage: 86.3 KB

# %%
data.describe()
# Out:
#          CustomerID          A1          A2          A3          A4  \
# count  6.900000e+02  690.000000  690.000000  690.000000  690.000000
# mean   1.569047e+07    0.678261   31.568203    4.758725    1.766667
# std    7.150647e+04    0.467482   11.853273    4.978163    0.430063
# min    1.556571e+07    0.000000   13.750000    0.000000    1.000000
# 25%    1.563169e+07    0.000000   22.670000    1.000000    2.000000
# 50%    1.569016e+07    1.000000   28.625000    2.750000    2.000000
# 75%    1.575190e+07    1.000000   37.707500    7.207500    2.000000
# max    1.581544e+07    1.000000   80.250000   28.000000    3.000000
#
#                A5          A6          A7          A8          A9        A10  \
# count  690.000000  690.000000  690.000000  690.000000  690.000000  690.00000
# mean     7.372464    4.692754    2.223406    0.523188    0.427536    2.40000
# std      3.683265    1.992316    3.346513    0.499824    0.495080    4.86294
# ...

# %% [markdown]
# ## Finding the presence of missing values

# %%
data.isnull().sum()
# Out:
# CustomerID    0
# A1            0
# A2            0
# A3            0
# A4            0
# A5            0
# A6            0
# A7            0
# A8            0
# A9            0
# A10           0
# A11           0
# A12           0
# A13           0
# A14           0
# Class         0
# dtype: int64

# %% [markdown]
# **Hence, there are no missing values.**

# %%
# Checking the different values of the target variable
data.Class.unique()
# Out:
# array([0, 1])

# %% [markdown]
# ### Checking the balance in the dataset

# %%
sns.countplot(data.Class)

# %% [markdown]
# **The data is sufficiently balanced.**

# %%
g = sns.pairplot(data, hue="Class")
# Out:
# /home/heenal/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /home/heenal/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
sns.set(rc={'figure.figsize':(15,8)})
sns.heatmap(data.corr(),annot=True)

# %% [markdown]
# ### Observations:
# ```
# 1. A8 and A13 have sufficient correlation with the target variable - 'Class'.
# 2. A3 and A13 are also correlated.
# 3. A9 and A10 are correlated as well.
# ```

# %% [markdown]
# ## Bivariate Plots

# %%
data.A10.unique()
# Out:
# array([ 0, 11, 14,  2,  6,  3,  4,  7,  1,  8,  5, 12, 16,  9, 10, 15, 67,
#        17, 19, 40, 13, 20, 23])

# %%
sns.jointplot(x='A3', y='A13', data = data, kind='scatter')

# %%
sns.jointplot(x='A3', y='A13', data=data, kind='kde')

# %% [markdown]
# **A3 and A13 do not seem to have much correlation with each other.**

# %%
sns.set(rc={'figure.figsize':(7,5)})
sns.boxplot(x='Class', y='A13', data=data)

# %%
sns.countplot(x='A8', data=data, hue='Class')

# %% [markdown]
# ### Observation :
# ```
# This indicates a strong positive correlation of A8 with the target variable.
# ```

# %%
sns.countplot(x='A9', data=data, hue='Class')

# %% [markdown]
# ### Observation :
# ```
# This indicates that even A9 is positively correlated with the target variable.
# ```
